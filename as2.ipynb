# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("IRIS2.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             NaN          3.5           NaN          0.2     Iris-setosa
# 1           114.9          3.0           NaN          0.2     Iris-setosa
# 2             4.7          3.2           NaN          0.2     Iris-setosa
# 3             NaN          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    1
# sepal_width     0
# petal_length    3
# petal_width     0
# species         0
# dtype: int64

# %%
ndf=df
# ndf['sepal_length']=ndf['sepal_length'].fillna(ndf['sepal_length'].mean())
ndf=ndf.fillna(ndf.mean(numeric_only=True))

ndf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             6.6          3.5      3.807483          0.2     Iris-setosa
# 1           114.9          3.0      3.807483          0.2     Iris-setosa
# 2             4.7          3.2      3.807483          0.2     Iris-setosa
# 3             6.6          3.1      1.500000          0.2     Iris-setosa
# 4             5.0          3.6      1.400000          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0      5.200000          2.3  Iris-virginica
# 146           6.3          2.5      5.000000          1.9  Iris-virginica
# 147           6.5          3.0      5.200000          2.0  Iris-virginica
# 148           6.2          3.4      5.400000          2.3  Iris-virginica
# 149           5.9          3.0      5.100000          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.boxplot(column="sepal_length")
plt.show()

# %%
col=['sepal_length','petal_length']
df.boxplot(col)
plt.show()

# %%
x=df.sepal_length
y=df.petal_length
plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()
